# %% [markdown]
# <h2 align=center> Named Entity Recognition (NER) using LSTMs with Keras</h2>

# %% [markdown]
# ![jj.png](data:image/png;base64,...)

# %% [markdown]
# ### Modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
np.random.seed(0)
plt.style.use("ggplot")

import tensorflow as tf
print('Tensorflow version:', tf.__version__)
print('GPU detected:', tf.config.list_physical_devices('GPU'))
# Out:
# Tensorflow version: 2.5.0
# GPU detected: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ### Load and Explore the NER Dataset

# %% [markdown]
# *Essential info about tagged entities*:
# - geo = Geographical Entity
# - org = Organization
# - per = Person
# - gpe = Geopolitical Entity
# - tim = Time indicator
# - art = Artifact
# - eve = Event
# - nat = Natural Phenomenon

# %%
data = pd.read_csv("ner_dataset.csv", encoding="latin1")
data = data.fillna(method="ffill")
data.head(20)
# Out:
#      Sentence #           Word  POS    Tag
# 0   Sentence: 1      Thousands  NNS      O
# 1   Sentence: 1             of   IN      O
# 2   Sentence: 1  demonstrators  NNS      O
# 3   Sentence: 1           have  VBP      O
# 4   Sentence: 1        marched  VBN      O
# 5   Sentence: 1        through   IN      O
# 6   Sentence: 1         London  NNP  B-geo
# 7   Sentence: 1             to   TO      O
# 8   Sentence: 1        protest   VB      O
# 9   Sentence: 1            the   DT      O
# 10  Sentence: 1            war   NN      O
# 11  Sentence: 1             in   IN      O
# 12  Sentence: 1           Iraq  NNP  B-geo
# 13  Sentence: 1            and   CC      O
# 14  Sentence: 1         demand   VB      O
# 15  Sentence: 1            the   DT      O
# 16  Sentence: 1     withdrawal   NN      O
# 17  Sentence: 1             of   IN      O
# 18  Sentence: 1        British   JJ  B-gpe
# 19  Sentence: 1         troops  NNS      O

# %%
print("Unique words in corpus:", data['Word'].nunique())
print("Unique tags in corpus:", data['Tag'].nunique())
# Out:
# Unique words in corpus: 35178
# Unique tags in corpus: 17

# %%
words = list(set(data["Word"].values))
words.append("ENDPAD")
num_words = len(words)

# %%
tags = list(set(data["Tag"].values))
num_tags = len(tags)

# %% [markdown]
# ### Task 3: Retrieve Sentences and Corresponsing Tags

# %%
class SentenceGetter(object):
    def __init__(self, data):
        self.n_sent = 1
        self.data = data
        self.empty = False
        agg_func = lambda s: [(w, p, t) for w, p, t in zip(s["Word"].values.tolist(),
                                                           s["POS"].values.tolist(),
                                                           s["Tag"].values.tolist())]
        self.grouped = self.data.groupby("Sentence #").apply(agg_func)
        self.sentences = [s for s in self.grouped]
    
    def get_next(self):
        try:
            s = self.grouped["Sentence: {}".format(self.n_sent)]
            self.n_sent += 1
            return s
        except:
            return None

# %%
getter = SentenceGetter(data)
sentences = getter.sentences

# %%
sentences[0]
# Out:
# [('Thousands', 'NNS', 'O'),
#  ('of', 'IN', 'O'),
#  ('demonstrators', 'NNS', 'O'),
#  ('have', 'VBP', 'O'),
#  ('marched', 'VBN', 'O'),
#  ('through', 'IN', 'O'),
#  ('London', 'NNP', 'B-geo'),
#  ('to', 'TO', 'O'),
#  ('protest', 'VB', 'O'),
#  ('the', 'DT', 'O'),
#  ('war', 'NN', 'O'),
#  ('in', 'IN', 'O'),
#  ('Iraq', 'NNP', 'B-geo'),
#  ('and', 'CC', 'O'),
#  ('demand', 'VB', 'O'),
#  ('the', 'DT', 'O'),
#  ('withdrawal', 'NN', 'O'),
#  ('of', 'IN', 'O'),
#  ('British', 'JJ', 'B-gpe'),
#  ('troops', 'NNS', 'O'),
#  ('from', 'IN', 'O'),
#  ('that', 'DT', 'O'),
#  ('country', 'NN', 'O'),
#  ('.', '.', 'O')]

# %% [markdown]
# ### Define Mappings between Sentences and Tags

# %%
word2idx = {w: i + 1 for i, w in enumerate(words)}
tag2idx = {t: i for i, t in enumerate(tags)}

# %%
word2idx
# Out:
# {'justly': 1,
#  'gauge': 2,
#  'Looking': 3,
#  'Yaracuy': 4,
#  'Halabja': 5,
#  'Segundo': 6,
#  'features': 7,
#  'Marxists': 8,
#  'Liaoning': 9,
#  'Aral': 10,
#  'Akerson': 11,
#  'rivals': 12,
#  'Respublika': 13,
#  'acutely': 14,
#  'Suleyman': 15,
#  'intimidate': 16,
#  'banner': 17,
#  'servers': 18,
#  'TTF': 19,
#  'treaties': 20,
#  'luge': 21,
#  'sectarianism': 22,
#  'gross': 23,
#  'Bugojno': 24,
#  'Bagosora': 25,
#  'Adelie': 26,
#  'Fully': 27,
#  'suddenly': 28,
#  'blasphemous': 29,
#  'Time': 30,
#  'Jabr': 31,
#  'unravel': 32,
#  'tightens': 33,
#  'Raich': 34,
#  'Panjwayi': 35,
#  'shaken': 36,
#  'Tarmiyah': 37,
#  'Aye': 38,
#  '1967': 39,
#  'replace': 40,
#  'call': 41,
#  'Mest': 42,
#  'has': 43,
#  'mediated': 44,
#  'thinking': 45,
#  'Thermo': 46,
#  'discern': 47,
#  'Saleh': 48,
#  'Anjar': 49,
#  'normalcy': 50,
#  'Thousands': 51,
#  'moderates': 52,
#  '13,969': 53,
#  'heist': 54,
#  'founder': 55,
#  'Honest': 56,
#  'firmest': 57,
#  'fifteen-year': 58,
#  'Jalalzadeh': 59,
#  '325': 60,
#  'focus': 61,
#  'Commando': 62,
#  'Supper': 63,
#  'merging': 64,
#  'K-4': 65,
#  'starting': 66,
#  'six-carat': 67,
#  'interview': 68,
#  '4,100-seat': 69,
#  'Sulieman': 70,
#  'Sherpao': 71,
#  'deadline': 72,
#  'symbols': 73,
#  'snarled': 74,
#  'small-cell': 75,
#  'censors': 76,
#  'Mayen': 77,
#  'tectonic': 78,
#  'Achievement': 79,
#  'Alzouma': 80,
#  'susceptibility': 81,
#  'André': 82,
#  '2A': 83,
#  'malfunctioned': 84,
#  'Permanent': 85,
#  '277': 86,
#  'Davit': 87,
#  'houses': 88,
#  'Kravchenko': 89,
#  'Kuduna': 90,
#  'betraying': 91,
#  'Oliveira': 92,
#  'Helmut': 93,
#  'sixth': 94,
#  'U.S.-imposed': 95,
#  'producing': 96,
#  'lid': 97,
#  'Tartous': 98,
#  'macro-economic': 99,
#  'lobbyist': 100,
#  'self-government': 101,
#  'countercoups': 102,
#  'difficulties': 103,
#  'Arafat-allies': 104,
#  'repairing': 105,
#  'stays': 106,
#  'aid-distribution': 107,
#  'Surrounded': 108,
#  'Trans-Saharan': 109,
#  'airlifts': 110,
#  'Mersin': 111,
#  'waiters': 112,
#  'McAdams': 113,
#  '2-0': 114,
#  'Six': 115,
#  'Sahrawi': 116,
#  'vest': 117,
#  'Sultan': 118,
#  'densely-populated': 119,
#  'Ngwira': 120,
#  'Rita': 121,
#  'optical': 122,
#  'Melnichenko': 123,
#  'one-meter-tall': 124,
#  'Zanu-PF': 125,
#  'Bogota': 126,
#  'burdensome': 127,
#  're-issued': 128,
#  'please': 129,
#  'rabbis': 130,
#  'staged': 131,
#  'underground': 132,
#  'Jose': 133,
#  'directives': 134,
#  'Arjangi': 135,
#  'Landslides': 136,
#  'combatant': 137,
#  'Roed-Larsen': 138,
#  'seasonally': 139,
#  'Court': 140,
#  'Venus': 141,
#  'Maresca': 142,
#  'Mitch': 143,
#  'boyhood': 144,
#  'Russia-Austria': 145,
#  'Al-Enezi': 146,
#  'scholars': 147,
#  'machining': 148,
#  'rest': 149,
#  'sinking': 150,
#  'modernizes': 151,
#  'quench': 152,
#  'despised': 153,
#  'detail': 154,
#  'Monte': 155,
#  '60.98': 156,
#  'relationship': 157,
#  'Zakayev': 158,
#  'wealthy': 159,
#  'wealth-sharing': 160,
#  'Malian': 161,
#  'pitcher': 162,
#  'Sasae': 163,
#  'Sabrina': 164,
#  'Gye': 165,
#  'generally': 166,
#  'succeed': 167,
#  'house': 168,
#  'committee': 169,
#  'shops': 170,
#  '102': 171,
#  'km-wide': 172,
#  '164': 173,
#  'Thatcher': 174,
#  'Agartala': 175,
#  'TWA': 176,
#  'enclave': 177,
#  'competitors': 178,
#  'retroactively': 179,
#  'Bjoergen': 180,
#  'caw': 181,
#  'Hamas-ruled': 182,
#  'Mojave': 183,
#  'Mbabane': 184,
#  'fibroids': 185,
#  'gridlock': 186,
#  'channeling': 187,
#  'Shyam': 188,
#  'crowds': 189,
#  '5.7': 190,
#  'Silk': 191,
#  'north': 192,
#  'Muifa': 193,
#  'entertainment': 194,
#  'Badghis': 195,
#  'chicken': 196,
#  'clampdown': 197,
#  '3,000': 198,
#  'NATO': 199,
#  'shoot-down': 200,
#  'booking': 201,
#  'defensive': 202,
#  'bombmaking': 203,
#  'UDD': 204,
#  'unfit': 205,
#  'obsessed': 206,
#  'Andreu': 207,
#  'pre-recorded': 208,
#  'Uttarakhand': 209,
#  'Virunga': 210,
#  'two-state': 211,
#  'Costeira': 212,
#  'creator': 213,
#  'aisle': 214,
#  'united': 215,
#  'cheerless': 216,
#  'abundance': 217,
#  'tip': 218,
#  'misused': 219,
#  'miner': 220,
#  'Sixto': 221,
#  'EPRDF': 222,
#  'Eleven': 223,
#  'Panggabean': 224,
#  'Daley': 225,
#  'meddling': 226,
#  'stretching': 227,
#  'championship': 228,
#  'finds': 229,
#  'Norpro': 230,
#  'Markovic': 231,
#  'systems': 232,
#  'generals': 233,
#  'Shahar': 234,
#  'prison': 235,
#  'publicist': 236,
#  'Capua': 237,
#  'licensing': 238,
#  'liberate': 239,
#  "'m": 240,
#  'Cantarell': 241,
#  'PO/PSL': 242,
#  'APEC': 243,
#  'renegotiate': 244,
#  'Malta': 245,
#  'Jean-Marie': 246,
#  'Clipperton': 247,
#  'imports': 248,
#  'Sharm': 249,
#  'tougher': 250,
#  'key': 251,
#  'mortar': 252,
#  'tolerating': 253,
#  'Burt': 254,
#  'agrochemicals': 255,
#  'ranches': 256,
#  'Construction': 257,
#  'Ghalawiya': 258,
#  'Saipan': 259,
#  'lags': 260,
#  '4,123': 261,
#  'al-Hindawi': 262,
#  'extending': 263,
#  'favors': 264,
#  'ISI': 265,
#  'Azahari': 266,
#  'Beethoven': 267,
#  'fifth': 268,
#  'depending': 269,
#  'depth': 270,
#  'U.S.-Iranian': 271,
#  'Katarina': 272,
#  '73.83': 273,
#  'Doo-hwan': 274,
#  'Samawa': 275,
#  'Loney': 276,
#  'gateways': 277,
#  'Oregon': 278,
#  'flame': 279,
#  'Lombardi': 280,
#  '300-member': 281,
#  'him': 282,
#  'indifferent': 283,
#  'Morning': 284,
#  'downloads': 285,
#  'mules': 286,
#  'scanned': 287,
#  '101st': 288,
#  'Center': 289,
#  'Mahee': 290,
#  'Ebrahim': 291,
#  'remixed': 292,
#  'breaks': 293,
#  'Phuket': 294,
#  'nightingale': 295,
#  '248': 296,
#  'draining': 297,
#  'embarks': 298,
#  'Lage': 299,
#  '218-5': 300,
#  'archipelago': 301,
#  'motive': 302,
#  'ASB': 303,
#  'laboratory': 304,
#  'Pathe': 305,
#  'frantic': 306,
#  'voltage': 307,
#  'Parasol': 308,
#  'Bastion': 309,
#  'Federline': 310,
#  '85-years-old': 311,
#  'Gafir': 312,
#  'bone': 313,
#  'Magerovskiy': 314,
#  'boldly': 315,
#  '8,40,000': 316,
#  'Stalinist': 317,
#  'takeover': 318,
#  'Solidaria': 319,
#  'Boeing': 320,
#  'Kompas': 321,
#  'Detection': 322,
#  'neutron': 323,
#  'military-run': 324,
#  'Penh': 325,
#  'Peres': 326,
#  'Plata': 327,
#  'al-Nabaie': 328,
#  'tolls': 329,
#  'Deh': 330,
#  'Macedonians': 331,
#  'newborn': 332,
#  'Deshu': 333,
#  'watered': 334,
#  'Katyusha-type': 335,
#  'Eugene': 336,
#  'graduates': 337,
#  'packing': 338,
#  'interactive': 339,
#  'Copei': 340,
#  '20-year': 341,
#  '25-member': 342,
#  'Derek': 343,
#  'meantime': 344,
#  'homecoming': 345,
#  'wallet': 346,
#  'goodwill': 347,
#  'malnourished': 348,
#  '83': 349,
#  'Chandipur': 350,
#  'Election': 351,
#  'levees': 352,
#  'Titan': 353,
#  'Madden': 354,
#  'GORBACHEV': 355,
#  'Liberation': 356,
#  'Southern': 357,
#  'pro-Tamil': 358,
#  'laying': 359,
#  'Novo-Filya': 360,
#  'Parwan': 361,
#  'Spector': 362,
#  'Cabo': 363,
#  'vary': 364,
#  'ballots': 365,
#  'krona': 366,
#  'summer': 367,
#  'anti-independence': 368,
#  'flourish': 369,
#  'Figures': 370,
#  'OUATTARA': 371,
#  'Stabilization': 372,
#  'Kano': 373,
#  'Palestinian-Americans': 374,
#  'Next': 375,
#  'Admiral': 376,
#  'Larkin': 377,
#  'seat': 378,
#  'Mukasey': 379,
#  'Kristina': 380,
#  'Yugoslavian': 381,
#  '3,348': 382,
#  'ultimatum': 383,
#  'tire': 384,
#  'Victor': 385,
#  'censored': 386,
#  'Rally': 387,
#  'I.A.E.A': 388,
#  'Yu': 389,
#  'cousins': 390,
#  'Palm': 391,
#  'resolving': 392,
#  'Vera': 393,
#  'clad': 394,
#  'Sony': 395,
#  'hospital': 396,
#  'pathologically': 397,
#  'Teachers': 398,
#  'Jebel': 399,
#  "d'Ivoire": 400,
#  'Taiwanese-American': 401,
#  'Tahitian': 402,
#  'reality': 403,
#  'two-man': 404,
#  'Jens': 405,
#  'Merv': 406,
#  'carmaker': 407,
#  'names': 408,
#  'grenade': 409,
#  'inability': 410,
#  'dirty': 411,
#  'Makubalo': 412,
#  'defense': 413,
#  'vocals': 414,
#  'CRJ-200': 415,
#  'Goodwill': 416,
#  'Made': 417,
#  'faced': 418,
#  'aggressions': 419,
#  'Arnold': 420,
#  'guess': 421,
#  'spun': 422,
#  'widely': 423,
#  'faces': 424,
#  'medium-haul': 425,
#  'Ambassador': 426,
#  'Posada': 427,
#  'Gajdosova': 428,
#  'terminate': 429,
#  'regret': 430,
#  'Brazilian': 431,
#  'Mexico': 432,
#  'peanuts': 433,
#  'theme-park-like': 434,
#  'deadliness': 435,
#  'hierarchical': 436,
#  'repatriate': 437,
#  'checkups': 438,
#  'ayatollah': 439,
#  'forcers': 440,
#  'sued': 441,
#  'Because': 442,
#  '1850s': 443,
#  'enroll': 444,
#  'farther': 445,
#  'Ilham': 446,
#  'rock': 447,
#  'mutiny': 448,
#  'floor': 449,
#  'gained': 450,
#  'obstructing': 451,
#  'attorneys': 452,
#  'reformers': 453,
#  'Sohrab': 454,
#  'compassionate': 455,
#  'Carnegie': 456,
#  'Oberhausen': 457,
#  'Qinglin': 458,
#  'proliferators': 459,
#  'upgrading': 460,
#  'Demirel': 461,
#  'blank': 462,
#  'echoed': 463,
#  'Tolo': 464,
#  'Flashing': 465,
#  'compatible': 466,
#  'seeded': 467,
#  'Okie': 468,
#  'Proliferation': 469,
#  'New~York': 470,
#  'Micheletti': 471,
#  'PPP': 472,
#  'earth-moving': 473,
#  'KANGAROO': 474,
#  'contest': 475,
#  '4.75': 476,
#  'follow-up': 477,
#  'oceans': 478,
#  'Bu-young': 479,
#  'Dohuk': 480,
#  'dirt': 481,
#  'slyly': 482,
#  'scrap': 483,
#  'salivated': 484,
#  'Taking': 485,
#  'Telesur': 486,
#  'infrared': 487,
#  'triumph': 488,
#  'riverside': 489,
#  'Tomiaki': 490,
#  'toppled': 491,
#  'dollar': 492,
#  'Hakkari': 493,
#  'anti-fraud': 494,
#  'Coordinating': 495,
#  'Compaq': 496,
#  'downfall': 497,
#  'catheter': 498,
#  'overture': 499,
#  'year-old': 500,
#  'highest-level': 501,
#  'circular': 502,
#  'Gypsy': 503,
#  'thousand-strong': 504,
#  'tops': 505,
#  'recently-detained': 506,
#  'ambition': 507,
#  'Letterman': 508,
#  'Norm': 509,
#  'bottles': 510,
#  'fractures': 511,
#  'Mariann': 512,
#  'act': 513,
#  'spiraling': 514,
#  'mathematician': 515,
#  'Entertainment': 516,
#  'Fela': 517,
#  'Godfrey': 518,
#  'artwork': 519,
#  'bodily': 520,
#  'Milenkovic': 521,
#  'Duarte': 522,
#  'Talim': 523,
#  'kindergarten': 524,
#  'flying': 525,
#  'thinks': 526,
#  'creates': 527,
#  'Sabawi': 528,
#  'hindering': 529,
#  'Thief': 530,
#  'General': 531,
#  'Obaidullah': 532,
#  'Alvaro': 533,
#  'Askari': 534,
#  'resonated': 535,
#  'Chahine': 536,
#  'develop': 537,
#  'Rovnag': 538,
#  'caucuses': 539,
#  'Dmitri': 540,
#  'stormy': 541,
#  'Emmanuel': 542,
#  'Shivnarine': 543,
#  'ship-to-ship': 544,
#  'Bashar': 545,
#  'Mazlum-Der': 546,
#  '56': 547,
#  'en': 548,
#  'Democratic-controlled': 549,
#  'bounce': 550,
#  'overseas': 551,
#  'Zvyagintsev': 552,
#  'Eagle': 553,
#  'ensures': 554,
#  'concentrates': 555,
#  'Nebojsa': 556,
#  'universe': 557,
#  'targeted': 558,
#  'jungles': 559,
#  'serfdom': 560,
#  'US-Canada': 561,
#  'Finally': 562,
#  'Lubroth': 563,
#  'Mail': 564,
#  'Feinstein': 565,
#  'Asghari': 566,
#  'Slovaks': 567,
#  'Shirin': 568,
#  'undated': 569,
#  'Charlotte': 570,
#  'government-run': 571,
#  'Tammy': 572,
#  'conducive': 573,
#  'Lajcak': 574,
#  'wrapped': 575,
#  'emerging': 576,
#  'unreasonable': 577,
#  'tacit': 578,
#  'organize': 579,
#  'Jesper': 580,
#  'al-Adamiya': 581,
#  'pretended': 582,
#  'Novosibirsk': 583,
#  'Szmajdzinski': 584,
#  'images': 585,
#  '02-Jan': 586,
#  'al-Harith': 587,
#  'Kasuri': 588,
#  '70-year-old': 589,
#  'aggravating': 590,
#  'pillar': 591,
#  'superb': 592,
#  'France-Africa': 593,
#  'hasty': 594,
#  'measurable': 595,
#  'Aleman': 596,
#  'Yuschenko': 597,
#  'midst': 598,
#  "GM's": 599,
#  'Nations-mediated': 600,
#  'pointing': 601,
#  'blaming': 602,
#  'cuts': 603,
#  'cede': 604,
#  'overstaying': 605,
#  'Nateghi': 606,
#  'three-set': 607,
#  'miscommunication': 608,
#  'Avian': 609,
#  'arresting': 610,
#  '5,52,300': 611,
#  'kidnapped': 612,
#  'intra-Palestinian': 613,
#  'inter-American': 614,
#  'ethnic-Chinese': 615,
#  'Shoigu': 616,
#  'Saxby': 617,
#  'non-environmental': 618,
#  'profiting': 619,
#  'bomber': 620,
#  'Shidiac': 621,
#  'improperly': 622,
#  'solid': 623,
#  'Odyssey': 624,
#  'Fatal': 625,
#  'brutally': 626,
#  'stand': 627,
#  'Damascus-based': 628,
#  'Rish': 629,
#  'Worshipers': 630,
#  '71-year-old': 631,
#  'Bajura': 632,
#  'annotations': 633,
#  'writer': 634,
#  'Karabila': 635,
#  'defusing': 636,
#  'yet': 637,
#  'recruiting': 638,
#  'Kesbir': 639,
#  'private': 640,
#  'agreed': 641,
#  '82-year-old': 642,
#  'caravan': 643,
#  'Challenger': 644,
#  '12.3': 645,
#  'Taher': 646,
#  'Opposing': 647,
#  'job': 648,
#  'Andrhra': 649,
#  'lenghty': 650,
#  'soprano': 651,
#  'cooperative': 652,
#  'controlled': 653,
#  'emirate': 654,
#  'lift': 655,
#  'delegated': 656,
#  'Saints': 657,
#  'much-improved': 658,
#  'glory': 659,
#  'Deir': 660,
#  'Ossetian': 661,
#  'no-man': 662,
#  'realities': 663,
#  'starred': 664,
#  'Host': 665,
#  '7.7': 666,
#  'Filsi': 667,
#  'Bartlett': 668,
#  'conquered': 669,
#  'Norsemen': 670,
#  'Giustra': 671,
#  'high-altitude': 672,
#  'LTTE': 673,
#  'anti-violence': 674,
#  'hauling': 675,
#  'Sherpa': 676,
#  'Employers': 677,
#  'drives': 678,
#  'turnout': 679,
#  'stalking': 680,
#  'sanctuaries': 681,
#  'Ankunda': 682,
#  'sewage': 683,
#  'Domachowska': 684,
#  'violence-ridden': 685,
#  'pig-borne': 686,
#  'grid': 687,
#  'hauled': 688,
#  'career': 689,
#  'rout': 690,
#  '375': 691,
#  'Hongyao': 692,
#  'signal': 693,
#  'complicate': 694,
#  'Clarkson': 695,
#  'Abqaiq': 696,
#  're-opened': 697,
#  'Tehrik-e-Taliban': 698,
#  'Steyn': 699,
#  'quotas': 700,
#  'Singnaghi': 701,
#  'larger-than-normal': 702,
#  'Casey': 703,
#  'favoring': 704,
#  'vestige': 705,
#  'Sinmun': 706,
#  'Srebrenica': 707,
#  'laughter': 708,
#  'Bosnian': 709,
#  'cattle': 710,
#  'Merimee': 711,
#  'de-facto': 712,
#  'Kjetil': 713,
#  'Khalikov': 714,
#  'cash-only': 715,
#  'suspects': 716,
#  'fenced': 717,
#  'SWAPO': 718,
#  'honor': 719,
#  'Makhaya': 720,
#  'Telephone': 721,
#  '1419': 722,
#  'Cotter': 723,
#  'showcasing': 724,
#  'Patil': 725,
#  'Alstom': 726,
#  'succeeded': 727,
#  '2,300': 728,
#  'merchants': 729,
#  'facilitate': 730,
#  'Traian': 731,
#  'season-opening': 732,
#  'collectively': 733,
#  'SAMBI': 734,
#  'immigrant': 735,
#  'Delhi-based': 736,
#  'Nanjing': 737,
#  'pre-launch': 738,
#  'strong': 739,
#  'ricocheted': 740,
#  'retreating': 741,
#  'Hearing': 742,
#  'likened': 743,
#  'edition': 744,
#  'Henk': 745,
#  'addicts': 746,
#  'symptoms': 747,
#  'Ahafo': 748,
#  'clergy': 749,
#  'Olympic': 750,
#  'developments': 751,
#  'contempt': 752,
#  'deliveries': 753,
#  'Simba': 754,
#  'high-grade': 755,
#  'rarely': 756,
#  'Dichter': 757,
#  'passing': 758,
#  'Masahiko': 759,
#  'Placid': 760,
#  'designer': 761,
#  'bested': 762,
#  'starving': 763,
#  'Aftenposten': 764,
#  'sit-in': 765,
#  'Arla': 766,
#  'feuding': 767,
#  'Dera': 768,
#  'Soviet-imposed': 769,
#  'Verbytsky': 770,
#  '40-car': 771,
#  'opposes': 772,
#  'string': 773,
#  'skipped': 774,
#  'handed': 775,
#  'Awe': 776,
#  'chink': 777,
#  'able': 778,
#  'Machimura': 779,
#  'Istanbul': 780,
#  'subsistence-based': 781,
#  'kph': 782,
#  'el-Hadary': 783,
#  '297': 784,
#  'Gibraltarians': 785,
#  'Batiz': 786,
#  'tuneup': 787,
#  'Barrett': 788,
#  'Sawyer': 789,
#  'self-financing': 790,
#  'Clijsters': 791,
#  'daring': 792,
#  'lobbies': 793,
#  'Progressive': 794,
#  'Warren': 795,
#  'Zebari': 796,
#  'firsts': 797,
#  'Hayabullah': 798,
#  'converging': 799,
#  'Pyongyang': 800,
#  'prevail': 801,
#  'lslamic': 802,
#  'competing': 803,
#  'downstream': 804,
#  'Ravalomanana': 805,
#  'led-invasion': 806,
#  'Roswell': 807,
#  'Kanan': 808,
#  '3,04,569': 809,
#  'Bowman': 810,
#  'prospered': 811,
#  'ruining': 812,
#  'glacier': 813,
#  'most-wanted': 814,
#  'closely-watched': 815,
#  'modify': 816,
#  'repressed': 817,
#  'motorized': 818,
#  'Nov.': 819,
#  'Rehman': 820,
#  'precipitation': 821,
#  'corruption': 822,
#  'divorced': 823,
#  'Bergersen': 824,
#  'Markac': 825,
#  'Giant': 826,
#  'neigh': 827,
#  '58.28': 828,
#  'differed': 829,
#  'busier': 830,
#  'vain': 831,
#  'Un': 832,
#  'Mastung': 833,
#  'births': 834,
#  '57.7': 835,
#  'needy': 836,
#  '24th': 837,
#  'Shaikan': 838,
#  'Securities': 839,
#  'Farabaugh': 840,
#  'e-mailed': 841,
#  'Lama': 842,
#  'forget': 843,
#  'inefficiencies': 844,
#  'Saffir-Simpson': 845,
#  'pelt': 846,
#  'Vaziri-Hamaneh': 847,
#  'Arusha': 848,
#  'wage': 849,
#  'Heiligendamm': 850,
#  'incredible': 851,
#  '1.224': 852,
#  'H5-type': 853,
#  'Kupwara': 854,
#  'mid-December': 855,
#  'electrocuted': 856,
#  'exploiting': 857,
#  'instituting': 858,
#  'prototype': 859,
#  'march': 860,
#  'MOSHOESHOE': 861,
#  'privilege': 862,
#  'bird-flu': 863,
#  'Nasser': 864,
#  '17.09': 865,
#  'Metin': 866,
#  '747-8': 867,
#  'defied': 868,
#  'Julian': 869,
#  'sweeps': 870,
#  'disarmed': 871,
#  'Arcega': 872,
#  'activity': 873,
#  'Namibia': 874,
#  'sparking': 875,
#  'barbed': 876,
#  'congratuatlions': 877,
#  'exclude': 878,
#  'scrubbed': 879,
#  'ex-Clinton': 880,
#  'condemns': 881,
#  'neglected': 882,
#  'Cars': 883,
#  'undersea': 884,
#  'Steve': 885,
#  'fine-tuning': 886,
#  'Perhaps': 887,
#  'religion': 888,
#  '11,000': 889,
#  'detractors': 890,
#  'conglomerate': 891,
#  'testify': 892,
#  'silver': 893,
#  'epidemic': 894,
#  'doing': 895,
#  'deploring': 896,
#  'technology': 897,
#  '1942': 898,
#  'Balenciaga': 899,
#  'submarine': 900,
#  'Balah': 901,
#  'grasp': 902,
#  'GlaxoSmithKline': 903,
#  'chapters': 904,
#  'catching': 905,
#  'Changqi': 906,
#  'hill-top': 907,
#  'Paktiawal': 908,
#  'Transocean': 909,
#  'anti-Deby': 910,
#  'deaths': 911,
#  '2.75': 912,
#  'Hasan': 913,
#  'Students': 914,
#  'disengagement': 915,
#  'Hib': 916,
#  'Center-left': 917,
#  'Anni': 918,
#  'cancel': 919,
#  'defenders': 920,
#  'Fires': 921,
#  'supplying': 922,
#  'unanimously': 923,
#  'establish': 924,
#  'Addington': 925,
#  'cross': 926,
#  'Danielle': 927,
#  'Tanzania-based': 928,
#  '23-25': 929,
#  'Charai': 930,
#  'evict': 931,
#  'anti-cholesterol': 932,
#  'rebounding': 933,
#  'snows': 934,
#  'doubling': 935,
#  'Ugly': 936,
#  'Hasegawa': 937,
#  'forgotten': 938,
#  'VE': 939,
#  'Care': 940,
#  'Competition': 941,
#  '40,000': 942,
#  'Belet': 943,
#  'pie': 944,
#  'pugilists': 945,
#  'gas-separation': 946,
#  'al-Rashid': 947,
#  'officially': 948,
#  'free-market': 949,
#  'Kansas': 950,
#  'westward': 951,
#  'dignitary': 952,
#  'heavily-militarized': 953,
#  'Germ': 954,
#  'structuring': 955,
#  '2000': 956,
#  'gasping': 957,
#  'Yokosuka': 958,
#  'painted': 959,
#  'belts': 960,
#  'Bheri': 961,
#  'misanthropic': 962,
#  'Ancient': 963,
#  'hillsides': 964,
#  '384': 965,
#  'student': 966,
#  'Benham': 967,
#  'disgruntled': 968,
#  'Trawlers': 969,
#  'decline': 970,
#  'protection': 971,
#  'converting': 972,
#  'Confederation': 973,
#  'accusing': 974,
#  'pillars': 975,
#  'genuine': 976,
#  'Oceanic': 977,
#  '2000s': 978,
#  'al-Shaer': 979,
#  'Tenerife': 980,
#  'malaria': 981,
#  'stove': 982,
#  'million-dollar': 983,
#  'neutralizing': 984,
#  'Kutesa': 985,
#  '5,000': 986,
#  'testing': 987,
#  'Pinerolo': 988,
#  'loans': 989,
#  'Inequality': 990,
#  'inbalance': 991,
#  'Sander': 992,
#  'ingratitude': 993,
#  'Pennetta': 994,
#  'language': 995,
#  'noise': 996,
#  'pledge': 997,
#  'younger': 998,
#  'Cemetery': 999,
#  'unprecedented': 1000,
#  ...}

# %% [markdown]
# ### Padding Input Sentences and Creating Train/Test Splits

# %%
plt.hist([len(s) for s in sentences], bins=50)
plt.show()

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences

max_len = 50

X = [[word2idx[w[0]] for w in s] for s in sentences]
X = pad_sequences(maxlen=max_len, sequences=X, padding="post", value=num_words-1)

y = [[tag2idx[w[2]] for w in s] for s in sentences]
y = pad_sequences(maxlen=max_len, sequences=y, padding="post", value=tag2idx["O"])

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %% [markdown]
# ### Build and Compile a Bidirectional LSTM Model

# %%
from tensorflow.keras import Model, Input
from tensorflow.keras.layers import LSTM, Embedding, Dense
from tensorflow.keras.layers import TimeDistributed, SpatialDropout1D, Bidirectional

# %%
input_word = Input(shape=(max_len,))
model = Embedding(input_dim=num_words, output_dim=50, input_length=max_len)(input_word)
model = SpatialDropout1D(0.1)(model)
model = Bidirectional(LSTM(units=100, return_sequences=True, recurrent_dropout=0.1))(model)
out = TimeDistributed(Dense(num_tags, activation="softmax"))(model)
model = Model(input_word, out)
model.summary()
# Out:
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(None, 50)]              0
# _________________________________________________________________
# embedding_6 (Embedding)      (None, 50, 50)            1758950
# _________________________________________________________________
# spatial_dropout1d_6 (Spatial (None, 50, 50)            0
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 50, 200)           120800
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 50, 17)            3417
# =================================================================
# Total params: 1,883,167
# Trainable params: 1,883,167
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="adam",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

# %% [markdown]
# ### Task 7: Train the Model

# %%
# !pip install livelossplot

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from livelossplot.tf_keras import PlotLossesCallback

# %%
# %%time

chkpt = ModelCheckpoint("model_weights.h5", monitor='val_loss',verbose=1, save_best_only=True, save_weights_only=True, mode='min')

early_stopping = EarlyStopping(monitor='val_accuracy', min_delta=0, patience=1, verbose=0, mode='max', baseline=None, restore_best_weights=False)

callbacks = [PlotLossesCallback(), chkpt, early_stopping]

history = model.fit(
    x=x_train,
    y=y_train,
    validation_data=(x_test,y_test),
    batch_size=32, 
    epochs=3,
    callbacks=callbacks,
    verbose=1
)
# Out:
# accuracy
# 	training         	 (min:    0.959, max:    0.988, cur:    0.988)
# 	validation       	 (min:    0.981, max:    0.985, cur:    0.985)
# Loss
# 	training         	 (min:    0.038, max:    0.178, cur:    0.038)
# 	validation       	 (min:    0.049, max:    0.065, cur:    0.049)
#
# Epoch 00003: val_loss improved from 0.05234 to 0.04889, saving model to model_weights.h5
# CPU times: user 29min 32s, sys: 3min 41s, total: 33min 14s
# Wall time: 20min 34s

# %% [markdown]
# ### Evaluate Named Entity Recognition Model

# %%
model.evaluate(x_test, y_test)
# Out:
# 300/300 [==============================] - 8s 26ms/step - loss: 0.0489 - accuracy: 0.9853
# [0.048886433243751526, 0.9852564930915833]

# %%
i = np.random.randint(0, x_test.shape[0]) #659
p = model.predict(np.array([x_test[i]]))
p = np.argmax(p, axis=-1)
y_true = y_test[i]
print("{:15}{:5}\t {}\n".format("Word", "True", "Pred"))
print("-" *30)
for w, true, pred in zip(x_test[i], y_true, p[0]):
    print("{:15}{}\t{}".format(words[w-1], tags[true], tags[pred]))
# Out:
# Word           True 	 Pred
#
# ------------------------------
# The            O	O
# military       O	O
# says           O	O
# it             O	O
# is             O	O
# investigating  O	O
# both           O	O
# deaths         O	O
# .              O	O
# Galo           O	O
# Galo           O	O
# Galo           O	O
# Galo           O	O
# Galo           O	O
# Galo           O	O
# Galo           O	O
# Galo           O	O
# Galo           O	O
# Galo           O	O
# Galo           O	O
# Galo           O	O
# Galo           O	O
# Galo           O	O
# Galo           O	O
# Galo           O	O
# Galo           O	O
# Galo           O	O
# Galo           O	O
# Galo           O	O
# Galo           O	O
# Galo           O	O
# Galo           O	O
# Galo           O	O
# Galo           O	O
# Galo           O	O
# Galo           O	O
# Galo           O	O
# Galo           O	O
# Galo           O	O
# Galo           O	O
# Galo           O	O
# Galo           O	O
# Galo           O	O
# Galo           O	O
# Galo           O	O
# Galo           O	O
# Galo           O	O
# Galo           O	O
# Galo           O	O
# Galo           O	O
